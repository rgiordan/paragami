# %%
import jax
import jax.numpy as jnp
import numpy as np
from jax import grad, hessian, jit, vmap

def logprob_fun(mu, x):
    return np.sum(0.5 * (mu - x)**2)

grad_fun = jit(grad(logprob_fun))
hess_fun = jit(hessian(logprob_fun))

# %% [markdown]
# # Paragami debugging

# %%
import paragami
import copy
import unittest
from numpy.testing import assert_array_almost_equal
import scipy as sp
import scipy as osp

import itertools
import json
import collections

import time
# Out:
# /home/rgiordan/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/lib/xla_bridge.py:130: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
def jax_random(shape):
    key = jax.random.PRNGKey(42)
    if not type(shape) is tuple:
        shape = (shape, )
    return jax.random.uniform(key, shape=shape, dtype='float64')

# %% [markdown]
# # Profiling

# %%
class DummyTest(unittest.TestCase):
    pass
testcase = DummyTest()
self = DummyTest()
check_equal = assert_array_almost_equal

# array_pattern = paragami.NumericArrayPattern(
#     shape=(4, ), lb=-1, ub=10.0)
# pattern = paragami.PatternArray((2, 3), array_pattern)

pattern = paragami.PSDSymmetricMatrixPattern(100)

#pattern = paragami.NumericArrayPattern(shape=(500, 10, 10), lb=-1, ub=10.0)

# %%
import cProfile
import pstats
valid_value = pattern.random()

# Execute required methods.
empty_val = pattern.empty(valid=True)
flat_val = pattern.flatten(empty_val, free=True, validate_value=False)
profile = True

if profile:
    pr = cProfile.Profile()
    pr.enable()

jit_flatten = jax.jit(lambda val: pattern.flatten(empty_val, free=True, validate_value=True))
jit_fold = jax.jit(lambda flat_val: pattern.fold(flat_val, free=True, validate_value=True))

jit_flatten(empty_val)
jit_fold(flat_val)

tic = time.time()
for _ in range(500):
    #pattern.flatten(empty_val, free=False, validate_value=False)
    jit_flatten(empty_val)
    #jit_fold(flat_val)
    
tic = time.time() - tic; print(tic)

if profile:
    pr.disable()
# Out:
# 0.0442051887512207

# %%
ps = pstats.Stats(pr).strip_dirs().sort_stats('cumulative')
ps.print_stats()
# Out:
#          386160 function calls (386158 primitive calls) in 0.490 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         9    0.000    0.000    0.489    0.054 interactiveshell.py:3302(run_code)
#         9    0.000    0.000    0.489    0.054 {built-in method builtins.exec}
#         1    0.019    0.019    0.479    0.479 <ipython-input-5-959f729a1ed8>:21(<module>)
#      5001    0.005    0.000    0.460    0.000 <ipython-input-5-959f729a1ed8>:14(<lambda>)
#      5001    0.007    0.000    0.456    0.000 psdmatrix_patterns.py:295(flatten)
#      5001    0.007    0.000    0.437    0.000 lax_numpy.py:1153(ravel)
#      5002    0.004    0.000    0.407    0.000 lax_numpy.py:1109(reshape)
#      5002    0.011    0.000    0.403    0.000 lax_numpy.py:1138(_reshape_method)
#      5002    0.006    0.000    0.388    0.000 lax_numpy.py:1126(_reshape)
#      5002    0.015    0.000    0.378    0.000 lax.py:657(reshape)
#      5002    0.006    0.000    0.317    0.000 core.py:271(bind)
#      5001    0.011    0.000    0.293    0.000 lax.py:3278(_reshape_impl)
#      5001    0.016    0.000    0.261    0.000 xla.py:222(apply_primitive)
#      5001    0.154    0.000    0.231    0.000 xla.py:327(_execute_compiled_primitive)
#      5001    0.004    0.000    0.064    0.000 xla.py:329(<listcomp>)
#      5002    0.006    0.000    0.061    0.000 xla.py:117(device_put)
#      5002    0.004    0.000    0.050    0.000 xla.py:1149(_device_put_device_array)
#     20012    0.022    0.000    0.041    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     15006    0.009    0.000    0.033    0.000 <__array_function__ internals>:2(shape)
#      5002    0.019    0.000    0.032    0.000 xla.py:1154(_copy_device_array_to_device)
#      5006    0.004    0.000    0.023    0.000 core.py:1064(canonicalize_shape)
#      5001    0.004    0.000    0.023    0.000 <__array_function__ internals>:2(size)
# 5023/5021    0.016    0.000    0.019    0.000 util.py:29(safe_map)
#      5003    0.007    0.000    0.018    0.000 core.py:722(find_top_trace)
#      5002    0.003    0.000    0.014    0.000 xla.py:1178(_force)
#      5006    0.007    0.000    0.011    0.000 {built-in method builtins.max}
#      5002    0.010    0.000    0.011    0.000 lazy.py:143(is_trivial)
#      5002    0.003    0.000    0.011    0.000 psdmatrix_patterns.py:250(validate_folded)
#      5001    0.007    0.000    0.010    0.000 lax.py:3289(_is_singleton_reshape)
#      5004    0.003    0.000    0.010    0.000 config.py:134(__getattr__)
#         1    0.000    0.000    0.010    0.010 <ipython-input-5-959f729a1ed8>:18(<module>)
#         1    0.000    0.000    0.010    0.010 api.py:152(f_jitted)
#         1    0.000    0.000    0.010    0.010 core.py:1133(bind)
#         1    0.000    0.000    0.010    0.010 core.py:1113(call_bind)
#         1    0.000    0.000    0.010    0.010 xla.py:525(_xla_call_impl)
#     15006    0.006    0.000    0.010    0.000 fromnumeric.py:1903(shape)
#      5001    0.003    0.000    0.010    0.000 fromnumeric.py:3079(size)
#         1    0.000    0.000    0.009    0.009 linear_util.py:216(memoized_fun)
#         1    0.000    0.000    0.009    0.009 xla.py:584(_xla_callable)
#      5002    0.003    0.000    0.008    0.000 xla.py:215(arg_spec)
#         1    0.008    0.008    0.008    0.008 xla.py:322(_backend_compile)
#      5002    0.006    0.000    0.008    0.000 psdmatrix_patterns.py:242(_validate_folded_shape)
#      5002    0.007    0.000    0.007    0.000 xla_bridge.py:173(get_device_backend)
#      5005    0.005    0.000    0.007    0.000 config.py:59(read)
#      5001    0.003    0.000    0.007    0.000 xla.py:1012(size)
#     10004    0.007    0.000    0.007    0.000 xla.py:979(__init__)
#      5003    0.005    0.000    0.006    0.000 xla.py:158(abstractify)
#      5002    0.004    0.000    0.006    0.000 xla.py:136(canonicalize_dtype)
#     10006    0.006    0.000    0.006    0.000 util.py:191(prod)
#      5003    0.003    0.000    0.005    0.000 core.py:948(__hash__)
#     20004    0.005    0.000    0.005    0.000 xla.py:1004(shape)
#      5002    0.003    0.000    0.004    0.000 lax_numpy.py:1116(_compute_newshape)
#      5004    0.003    0.000    0.004    0.000 core.py:723(<genexpr>)
#     20059    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#     10052    0.003    0.000    0.003    0.000 {built-in method builtins.isinstance}
#      5010    0.002    0.000    0.002    0.000 core.py:1058(_canonicalize_dimension)
#      5002    0.002    0.000    0.002    0.000 xla.py:1133(is_device_constant)
#      5005    0.002    0.000    0.002    0.000 config.py:72(check_exists)
#     15006    0.002    0.000    0.002    0.000 fromnumeric.py:1899(_shape_dispatcher)
#      5003    0.002    0.000    0.002    0.000 {built-in method builtins.hash}
#     10011    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#     10030    0.001    0.000    0.002    0.000 {built-in method builtins.next}
#     10002    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#      5002    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#      5003    0.001    0.000    0.001    0.000 base_patterns.py:160(_free_with_default)
#      5001    0.001    0.000    0.001    0.000 fromnumeric.py:3075(_size_dispatcher)
#      5002    0.001    0.000    0.001    0.000 xla.py:72(identity)
#         1    0.000    0.000    0.001    0.001 partial_eval.py:373(trace_to_jaxpr)
#         1    0.000    0.000    0.001    0.001 linear_util.py:137(call_wrapped)
#         3    0.000    0.000    0.000    0.000 partial_eval.py:430(trace_to_subjaxpr)
#         1    0.000    0.000    0.000    0.000 xla.py:371(jaxpr_subcomp)
#         9    0.000    0.000    0.000    0.000 codeop.py:132(__call__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:15(<lambda>)
#         1    0.000    0.000    0.000    0.000 psdmatrix_patterns.py:305(fold)
#         1    0.000    0.000    0.000    0.000 xla.py:756(_execute_compiled)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:17(<module>)
#         3    0.000    0.000    0.000    0.000 {method 'send' of 'generator' objects}
#         1    0.000    0.000    0.000    0.000 partial_eval.py:137(process_primitive)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:143(default_process_primitive)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:498(tracers_to_jaxpr)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:26(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         6    0.000    0.000    0.000    0.000 util.py:91(partial)
#         1    0.000    0.000    0.000    0.000 source_info_util.py:27(user_frame)
#         1    0.000    0.000    0.000    0.000 xla.py:77(_make_unit)
#         2    0.000    0.000    0.000    0.000 iostream.py:386(write)
#         1    0.000    0.000    0.000    0.000 lax.py:1863(standard_abstract_eval)
#         6    0.000    0.000    0.000    0.000 functools.py:44(update_wrapper)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:315(constant)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:15(<module>)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:390(_ndarray_constant_handler)
#         1    0.000    0.000    0.000    0.000 api.py:92(jit)
#         1    0.000    0.000    0.000    0.000 core.py:1343(pp_eqn_compact)
#         3    0.000    0.000    0.000    0.000 iostream.py:197(schedule)
#         1    0.000    0.000    0.000    0.000 xla.py:716(_xla_callable_args)
#         1    0.000    0.000    0.000    0.000 lax.py:3309(_reshape_shape_rule)
#         1    0.000    0.000    0.000    0.000 xla.py:1312(_pval_to_result_handler)
#         1    0.000    0.000    0.000    0.000 xla.py:728(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2194(atleast_1d)
#         1    0.000    0.000    0.000    0.000 xla.py:102(aval_to_result_handler)
#         1    0.000    0.000    0.000    0.000 core.py:1405(pp_kv_pairs)
#         1    0.000    0.000    0.000    0.000 xla.py:108(array_result_handler)
#        11    0.000    0.000    0.000    0.000 contextlib.py:85(__exit__)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2232(array)
#         1    0.000    0.000    0.000    0.000 xla.py:758(<listcomp>)
#         4    0.000    0.000    0.000    0.000 partial_eval.py:515(getvar)
#        77    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        11    0.000    0.000    0.000    0.000 contextlib.py:157(helper)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:297(_numpy_array_constant)
#         1    0.000    0.000    0.000    0.000 util.py:121(toposort)
#         4    0.000    0.000    0.000    0.000 core.py:931(__init__)
#         3    0.000    0.000    0.000    0.000 socket.py:357(send)
#        11    0.000    0.000    0.000    0.000 contextlib.py:79(__enter__)
#         1    0.000    0.000    0.000    0.000 xla.py:746(_xla_param)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         8    0.000    0.000    0.000    0.000 core.py:529(__getattr__)
#         3    0.000    0.000    0.000    0.000 core.py:1045(raise_to_shaped)
#         1    0.000    0.000    0.000    0.000 core.py:1407(<listcomp>)
#         2    0.000    0.000    0.000    0.000 core.py:207(<lambda>)
#        11    0.000    0.000    0.000    0.000 contextlib.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:489(recipe_to_eqn)
#         2    0.000    0.000    0.000    0.000 core.py:1402(pp_kv_pair)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         2    0.000    0.000    0.000    0.000 core.py:168(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 pprint_util.py:36(__rshift__)
#         9    0.000    0.000    0.000    0.000 pprint_util.py:53(pp)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2324(all)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.000    0.000 api_util.py:27(wraps)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:269(host_count)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        18    0.000    0.000    0.000    0.000 compilerop.py:138(extra_flags)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.ConstantLiteral}
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:65(get_compile_options)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:264(host_ids)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:302(parameter)
#         1    0.000    0.000    0.000    0.000 xla.py:90(aval_to_xla_shape)
#         9    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#         1    0.000    0.000    0.000    0.000 lax.py:3326(_reshape_translation_rule)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:494(<listcomp>)
#         2    0.000    0.000    0.000    0.000 tree_util.py:47(tree_flatten)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:289(normalize_to_xla_dtypes)
#         1    0.000    0.000    0.000    0.000 xla.py:83(_make_array_shape)
#         1    0.000    0.000    0.000    0.000 __init__.py:525(log)
#         9    0.000    0.000    0.000    0.000 hooks.py:103(__call__)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Reshape}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#         2    0.000    0.000    0.000    0.000 iostream.py:323(_schedule_flush)
#         9    0.000    0.000    0.000    0.000 traitlets.py:545(__get__)
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:117(<lambda>)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         5    0.000    0.000    0.000    0.000 {built-in method jaxlib.pytree.flatten}
#         1    0.000    0.000    0.000    0.000 api_util.py:87(donation_vector)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Parameter}
#         9    0.000    0.000    0.000    0.000 partial_eval.py:351(aval)
#         2    0.000    0.000    0.000    0.000 util.py:23(safe_zip)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2236(any)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.array_shape}
#         1    0.000    0.000    0.000    0.000 xla.py:361(jaxpr_literals)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2275(_can_call_numpy_array)
#         1    0.000    0.000    0.000    0.000 xla.py:596(<listcomp>)
#         3    0.000    0.000    0.000    0.000 api_util.py:41(flatten_fun)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:381(make_computation_builder)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:463(new_eqn_recipe)
#         2    0.000    0.000    0.000    0.000 source_info_util.py:30(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Tuple}
#         2    0.000    0.000    0.000    0.000 partial_eval.py:66(unknown)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:112(new_arg)
#         1    0.000    0.000    0.000    0.000 core.py:99(subjaxprs)
#         1    0.000    0.000    0.000    0.000 api.py:80(_check_callable)
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.000    0.000 partial_eval.py:51(__new__)
#         1    0.000    0.000    0.000    0.000 linear_util.py:198(wrap_init)
#         1    0.000    0.000    0.000    0.000 source_info_util.py:49(current)
#         6    0.000    0.000    0.000    0.000 pprint_util.py:25(indent)
#         2    0.000    0.000    0.000    0.000 core.py:683(new_master)
#         2    0.000    0.000    0.000    0.000 core.py:701(new_sublevel)
#         1    0.000    0.000    0.000    0.000 util.py:152(check_toposort)
#         1    0.000    0.000    0.000    0.000 lazy.py:112(array)
#         1    0.000    0.000    0.000    0.000 xla.py:578(_xla_consts)
#        11    0.000    0.000    0.000    0.000 partial_eval.py:77(get_aval)
#         2    0.000    0.000    0.000    0.000 linear_util.py:185(transformation_with_aux)
#         1    0.000    0.000    0.000    0.000 pprint_util.py:49(__str__)
#         1    0.000    0.000    0.000    0.000 pprint_util.py:59(vcat)
#         1    0.000    0.000    0.000    0.000 __init__.py:1102(log)
#         3    0.000    0.000    0.000    0.000 core.py:716(full_lower)
#         2    0.000    0.000    0.000    0.000 tree_util.py:59(tree_unflatten)
#         9    0.000    0.000    0.000    0.000 traitlets.py:526(get)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 xla.py:475(jaxpr_replicas)
#         2    0.000    0.000    0.000    0.000 linear_util.py:189(<lambda>)
#        23    0.000    0.000    0.000    0.000 pprint_util.py:22(__init__)
#         1    0.000    0.000    0.000    0.000 core.py:89(jaxprs_in_params)
#         4    0.000    0.000    0.000    0.000 core.py:870(__init__)
#         1    0.000    0.000    0.000    0.000 dtypes.py:253(result_type)
#         1    0.000    0.000    0.000    0.000 util.py:158(_remove_duplicates)
#         2    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#         1    0.000    0.000    0.000    0.000 inspect.py:172(isgeneratorfunction)
#         9    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 xla.py:761(<listcomp>)
#         6    0.000    0.000    0.000    0.000 partial_eval.py:355(parents)
#         3    0.000    0.000    0.000    0.000 linear_util.py:126(wrap)
#         3    0.000    0.000    0.000    0.000 core.py:1094(process_env_traces)
#         9    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9d12c0}
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.get_traceback}
#         1    0.000    0.000    0.000    0.000 lax.py:5892(_check_user_dtype_supported)
#         1    0.000    0.000    0.000    0.000 api_util.py:96(rebase_donate_argnums)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:337(__init__)
#         1    0.000    0.000    0.000    0.000 tree_util.py:75(tree_leaves)
#         2    0.000    0.000    0.000    0.000 tree_util.py:79(tree_structure)
#         1    0.000    0.000    0.000    0.000 dtypes.py:248(dtype)
#         2    0.000    0.000    0.000    0.000 linear_util.py:88(val)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:20(<module>)
#         1    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#         1    0.000    0.000    0.000    0.000 api.py:223(_jit_is_disabled)
#         1    0.000    0.000    0.000    0.000 api.py:1643(_check_arg)
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:1276(user_global_ns)
#         1    0.000    0.000    0.000    0.000 __init__.py:1359(log)
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 lax_numpy.py:2276(<genexpr>)
#         1    0.000    0.000    0.000    0.000 xla.py:270(_device_from_arg_devices)
#         2    0.000    0.000    0.000    0.000 xla.py:481(<genexpr>)
#         1    0.000    0.000    0.000    0.000 xla.py:696(_xla_callable_device)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:179(device_count)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:202(devices)
#         2    0.000    0.000    0.000    0.000 xla_bridge.py:266(<genexpr>)
#         3    0.000    0.000    0.000    0.000 linear_util.py:122(__name__)
#         1    0.000    0.000    0.000    0.000 core.py:194(gensym)
#         2    0.000    0.000    0.000    0.000 core.py:372(full_raise)
#         1    0.000    0.000    0.000    0.000 core.py:1344(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 util.py:36(unzip2)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:28(<module>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 api.py:1649(_valid_jaxtype)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         1    0.000    0.000    0.000    0.000 inspect.py:159(isfunction)
#         1    0.000    0.000    0.000    0.000 weakref.py:484(setdefault)
#        10    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 lazy.py:38(__new__)
#        16    0.000    0.000    0.000    0.000 partial_eval.py:73(get_known)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:150(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:362(full_lower)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:493(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:540(<genexpr>)
#         2    0.000    0.000    0.000    0.000 linear_util.py:94(__nonzero__)
#         1    0.000    0.000    0.000    0.000 linear_util.py:175(transformation)
#         2    0.000    0.000    0.000    0.000 pprint_util.py:33(__add__)
#         9    0.000    0.000    0.000    0.000 pprint_util.py:54(<listcomp>)
#         1    0.000    0.000    0.000    0.000 converter.py:138(absl_to_standard)
#         1    0.000    0.000    0.000    0.000 core.py:156(new_jaxpr_eqn)
#         2    0.000    0.000    0.000    0.000 core.py:367(__init__)
#         2    0.000    0.000    0.000    0.000 core.py:612(next_level)
#         1    0.000    0.000    0.000    0.000 core.py:936(<lambda>)
#         2    0.000    0.000    0.000    0.000 linear_util.py:83(store)
#         1    0.000    0.000    0.000    0.000 xla_client.py:156(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         2    0.000    0.000    0.000    0.000 api.py:2008(_ensure_tuple)
#         1    0.000    0.000    0.000    0.000 core.py:67(__init__)
#         9    0.000    0.000    0.000    0.000 hooks.py:168(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 __init__.py:1544(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 base_patterns.py:193(flat_length)
#         2    0.000    0.000    0.000    0.000 lax.py:1864(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         2    0.000    0.000    0.000    0.000 xla.py:374(read)
#         3    0.000    0.000    0.000    0.000 xla.py:386(write)
#         1    0.000    0.000    0.000    0.000 xla.py:485(eqn_replicas)
#         1    0.000    0.000    0.000    0.000 xla.py:579(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 xla.py:580(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 api_util.py:37(get_name)
#         1    0.000    0.000    0.000    0.000 api_util.py:39(get_doc)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:146(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:147(<genexpr>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:433(<listcomp>)
#         4    0.000    0.000    0.000    0.000 linear_util.py:116(__init__)
#         6    0.000    0.000    0.000    0.000 pprint_util.py:26(<listcomp>)
#         3    0.000    0.000    0.000    0.000 pprint_util.py:50(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:618(push)
#         1    0.000    0.000    0.000    0.000 core.py:624(pop)
#         2    0.000    0.000    0.000    0.000 core.py:680(cur_sublevel)
#         2    0.000    0.000    0.000    0.000 core.py:935(<lambda>)
#         1    0.000    0.000    0.000    0.000 core.py:1088(apply_todos)
#         1    0.000    0.000    0.000    0.000 core.py:1101(<listcomp>)
#         1    0.000    0.000    0.000    0.000 util.py:138(<listcomp>)
#         3    0.000    0.000    0.000    0.000 util.py:155(<genexpr>)
#         1    0.000    0.000    0.000    0.000 util.py:240(wrap_name)
#         1    0.000    0.000    0.000    0.000 util.py:243(extend_name_stack)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-959f729a1ed8>:14(<module>)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2232(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:3244(compare)
#         1    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         4    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 lax.py:3323(_reshape_dtype_rule)
#         1    0.000    0.000    0.000    0.000 xla.py:181(apply_outfeed_rewriter)
#         1    0.000    0.000    0.000    0.000 xla.py:281(<genexpr>)
#         1    0.000    0.000    0.000    0.000 xla.py:582(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api_util.py:38(get_module)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:70(is_known)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:119(instantiate_const)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:441(<listcomp>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:445(instantiate_const_at)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:492(<listcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:590(__init__)
#         2    0.000    0.000    0.000    0.000 linear_util.py:80(__init__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2320(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 multiarray.py:635(result_type)
#         1    0.000    0.000    0.000    0.000 typing.py:1432(cast)

# %%
empty_val = pattern.empty(valid=False)


random_val = pattern.random()
pattern.flatten(random_val, free=False)

str(pattern)

pattern.empty_bool(True)

# Make sure to test != using a custom test.
testcase.assertTrue(pattern == pattern)




###############################
# Test folding and unfolding.
for free in [True, False, None]:
    for free_default in [True, False, None]:
        pattern.free_default = free_default
        if (free_default is None) and (free is None):
            with testcase.assertRaises(ValueError):
                flat_val = pattern.flatten(valid_value, free=free)
            with testcase.assertRaises(ValueError):
                folded_val = pattern.fold(flat_val, free=free)
        else:
            flat_val = pattern.flatten(valid_value, free=free)
            testcase.assertEqual(len(flat_val), pattern.flat_length(free))
            folded_val = pattern.fold(flat_val, free=free)
            check_equal(valid_value, folded_val)
            if hasattr(valid_value, 'shape'):
                testcase.assertEqual(valid_value.shape, folded_val.shape)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# # Generic Jax stuff

# %%
x = onp.random.random(100)
mu = onp.random.random(100)

# I would have expected this to get rid of the annoying warning but it does not.
cpu_device = jax.devices('cpu')[0]
jax.device_put(x, cpu_device);
jax.device_put(mu, cpu_device);

# %%
g = grad_fun(mu, x)
h = hess_fun(mu, x)
print(np.max(np.abs(g - (mu - x))))
print(np.max(np.abs(h - np.eye(100))))

# %%
# https://jax.readthedocs.io/en/latest/notebooks/Custom_derivative_rules_for_Python_code.html

# %%
from jax import custom_jvp
import jax.numpy as jnp

# f :: a -> b
@custom_jvp
def f(x):
    return jnp.sin(x)

# f_jvp :: (a, T a) -> (b, T b)
def f_jvp(primals, tangents):
    x, = primals
    t, = tangents
    return f(x), jnp.cos(x) * t

f.defjvp(f_jvp)

print(type(f(0.5)))

print('Use jax')
foo = jax.numpy.asarray(f(0.5) + 3)
print(foo, type(foo))
print(isinstance(foo, onp.ndarray))
print(isinstance(foo, jax.numpy.ndarray))

print('Use numpy')
foo = onp.asarray(f(0.5) + 3)
print(isinstance(foo, onp.ndarray))
print(isinstance(foo, jax.numpy.ndarray))

# %%
@custom_jvp
def f(x, y):
    return jnp.sin(x) * y

f.defjvps(lambda x_dot, primal_out, x, y: jnp.cos(x) * x_dot * y,
          lambda y_dot, primal_out, x, y: jnp.sin(x) * y_dot)

# %%
foo = np.array([1, 2, 3])
print(jax.ops.index_update(foo, [1, 2], [10, 20]))

foo = np.array([[1, 2], [3, 4]])
print(jax.ops.index_update(foo, [1, 2], [10, 20]))

inds = np.triu_indices(2)
print(inds)
print(jax.ops.index_update(foo, inds, [10, 20, 30]))

# %%
#jax.sp.logsumexp

# %%
vec = np.arange(0, 3, dtype=np.float32) + 1
np.diag(vec)

# %%
def _exp_matrix_diagonal(mat):
    assert mat.shape[0] == mat.shape[1]
    dim = mat.shape[0]
    diag_inds = (np.arange(dim), np.arange(dim))
    exp_diags = np.exp(np.diag(mat))
    return(jax.ops.index_update(mat, diag_inds, exp_diags))

def _log_matrix_diagonal(mat):
    assert mat.shape[0] == mat.shape[1]
    dim = mat.shape[0]
    diag_inds = (np.arange(dim), np.arange(dim))
    log_diags = np.log(np.diag(mat))
    return(jax.ops.index_update(mat, diag_inds, log_diags))

mat = onp.random.random((3, 3))
print(mat)
print(_exp_matrix_diagonal(mat))
print(jax.jacobian(_exp_matrix_diagonal)(mat))

# %%
np.triu_indices(5)

def pack_vec(vec, dim):
    assert len(vec) == dim * (dim + 1) / 2
    mat = np.zeros((dim, dim))
    inds = np.tril_indices(dim)
    return(jax.ops.index_update(mat, inds, vec))

vec = np.arange(0, 6, dtype=np.float32) + 1
print(vec.dtype)
print(pack_vec(vec, 3))

print('Raw:')
print(jax.jacobian(pack_vec)(vec, 3))

print('JIT:')
jac_fun = jit(jax.jacobian(pack_vec), static_argnums=1)
print(jac_fun(vec, 3))

# %%
# Fails

# @custom_jvp
# def replace_ind(x, v, i):
#     x[i] = v
#     return x

# replace_ind.defjvps(
#     lambda x_dot, ans, x, v, i: replace_ind(x_dot, 0.0, i),
#     lambda v_dot, ans, x, v, i: replace_ind(ans, v_dot, i),
#     None)

# x = np.array([1.0, 2.0, 3.5])
# replace_ind(x, 10.0, 1)

# %% [markdown]
# ## Why is jax slow?

# %%
import timeit
foo = np.random.random((100, 10, 7)) + 1
number = 1000


def _unconstrain_array(array, lb, ub, np):
    # Assume that the inputs obey the constraints, lb < ub and
    # lb <= array <= ub, which are checked in the pattern.
    if ub == float("inf"):
        if lb == -float("inf"):
            # For consistent behavior, never return a reference.
            # Note that deepcopy will cause jax to fail.
            return copy.copy(array)
        else:
            return np.log(array - lb)
    else:  # the upper bound is finite
        if lb == -float("inf"):
            return -1 * np.log(ub - array)
        else:
            return np.log(array - lb) - np.log(ub - array)

setup_str = "from __main__ import jnp, np, foo, _unconstrain_array"
print(timeit.timeit('_unconstrain_array(foo, lb=0.5, ub=10.0, np=jnp)', setup=setup_str, number=number))
print(timeit.timeit('_unconstrain_array(foo, lb=0.5, ub=10.0, np=np)', setup=setup_str, number=number))

# %%
import timeit
foo = np.random.random((100, 10, 7)) + 1
number = 5000

setup_str = "from __main__ import jnp, np, foo"
print(timeit.timeit('jnp.atleast_1d(foo)', setup=setup_str, number=number))
print(timeit.timeit('np.atleast_1d(foo)', setup=setup_str, number=number))

# %%
import timeit
foo = np.random.random((100, 10, 7)) + 1
number = 5000

setup_str = "from __main__ import jnp, np, foo"
print(timeit.timeit('jnp.all(foo < 0.)', setup=setup_str, number=number))
print(timeit.timeit('np.all(foo < 0.)', setup=setup_str, number=number))

# %%
import jax
import jax.numpy as jnp
import numpy as np

import timeit
foo = [ np.random.random((100, )) for _ in range(10) ]
number = 500

@jax.jit
def jitted_fun(x):
    return jnp.hstack(x)

setup_str = "from __main__ import jnp, np, foo, jitted_fun"
print(timeit.timeit('y = jnp.hstack(foo)', setup=setup_str, number=number))
print(timeit.timeit('y = jitted_fun(foo)', setup=setup_str, number=number))
print(timeit.timeit('y = np.hstack(foo)', setup=setup_str, number=number))

# %% [markdown]
# # Is this even going to work

# %%
class BasePattern():
    def __init__(self, scale):
        self._scale = scale + 1.0
    
    def fun(self, val):
        return val

class Pattern(BasePattern):
    
    def get_scale(self):
        return self._scale

    def fun(self, val):
        if self._scale < 0.0:
            return 0.0
        return self.get_scale() * val
    
pattern = Pattern(2.1)
      
jit_fun = jax.jit(pattern.fun)
print(jit_fun(5.0))

jit_grad = jax.jit(jax.grad(pattern.fun))
print(jit_grad(5.0))

# %% [markdown]
# # Profiling psd functions
#
# All these are actually comparable between jax and autograd.

# %%
import cProfile
import pstats
valid_value = pattern.random()

# Execute required methods.
profile = True

if profile:
    pr = cProfile.Profile()
    pr.enable()

from paragami.psdmatrix_patterns import \
    _vectorize_ld_matrix, _unvectorize_ld_matrix, \
    _pack_posdef_matrix, _unpack_posdef_matrix

mat = jax_random((30, 30))
mat = mat @ mat + 100 * np.eye(30)
val = _vectorize_ld_matrix(mat)
#jit_fun = jax.jit(_vectorize_ld_matrix); jit_fun(mat)
#jit_fun = jax.jit(_unvectorize_ld_matrix); jit_fun(val)
#jit_fun = jax.jit(_pack_posdef_matrix); jit_fun(mat)
jit_fun = jax.jit(_unpack_posdef_matrix); jit_fun(val)

tic = time.time()
for _ in range(100):
    jit_fun(val)
    
tic = time.time() - tic; print(tic)

if profile:
    pr.disable()

# %%
# ps = pstats.Stats(pr).strip_dirs().sort_stats('cumulative')
# ps.print_stats()
