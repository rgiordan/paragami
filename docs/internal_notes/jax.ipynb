# %%
import jax
import jax.numpy as jnp
import numpy as np
from jax import grad, hessian, jit, vmap

def logprob_fun(mu, x):
    return np.sum(0.5 * (mu - x)**2)

grad_fun = jit(grad(logprob_fun))
hess_fun = jit(hessian(logprob_fun))

# %% [markdown]
# # Paragami debugging

# %%
import paragami
import copy
import unittest
from numpy.testing import assert_array_almost_equal
import scipy as sp
import scipy as osp

import itertools
import json
import collections

import time
# Out:
# /home/rgiordan/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/lib/xla_bridge.py:130: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
def jax_random(shape):
    key = jax.random.PRNGKey(42)
    if not type(shape) is tuple:
        shape = (shape, )
    return jax.random.uniform(key, shape=shape, dtype='float64')

# %% [markdown]
# # Profiling

# %%
class DummyTest(unittest.TestCase):
    pass
testcase = DummyTest()
self = DummyTest()
check_equal = assert_array_almost_equal

# array_pattern = paragami.NumericArrayPattern(
#     shape=(4, ), lb=-1, ub=10.0)
# pattern = paragami.PatternArray((2, 3), array_pattern)

pattern = paragami.PSDSymmetricMatrixPattern(100)

#pattern = paragami.NumericArrayPattern(shape=(500, 10, 10), lb=-1, ub=10.0)

# %%
import cProfile
import pstats
valid_value = pattern.random()

# Execute required methods.
empty_val = pattern.empty(valid=True)
flat_val = pattern.flatten(empty_val, free=True, validate_value=False)
profile = True

if profile:
    pr = cProfile.Profile()
    pr.enable()


# jit_flatten = jax.jit(lambda val: pattern.flatten(empty_val, free=True, validate_value=True))
# jit_fold = jax.jit(lambda flat_val: pattern.fold(flat_val, free=True, validate_value=True))

jit_flatten = jax.jit(pattern.flatten, static_argnums=(1, 2))

jit_flatten(empty_val, True, True)
#jit_fold(flat_val)

tic = time.time()
for _ in range(500):
    #pattern.flatten(empty_val, free=False, validate_value=False)
    jit_flatten(empty_val, False, False)
    #jit_fold(flat_val)
    
tic = time.time() - tic; print(tic)

if profile:
    pr.disable()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-45c56ed03df8> in <module>
#      18 jit_flatten = jax.jit(pattern.flatten, static_argnums=(1, 2))
#      19
# ---> 20 jit_flatten(empty_val, True, True)
#      21 #jit_fold(flat_val)
#      22
#
# ~/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     169     flat_fun, out_tree = flatten_fun(f, in_tree)
#     170     out = xla.xla_call(flat_fun, *args_flat, device=device, backend=backend,
# --> 171                        name=flat_fun.__name__, donated_invars=donated_invars)
#     172     return tree_unflatten(out_tree(), out)
#     173
#
# ~/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1132
#    1133   def bind(self, fun, *args, **params):
# -> 1134     return call_bind(self, fun, *args, **params)
#    1135
#    1136   def process(self, trace, fun, tracers, params):
#
# ~/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1121   if top_trace is None:
#    1122     with new_sublevel():
# -> 1123       outs = primitive.impl(fun, *args, **params)
#    1124   else:
#    1125     tracers = map(top_trace.full_raise, args)
#
# ~/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     525 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
#     526   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
# --> 527                                *unsafe_map(arg_spec, args))
#     528   try:
#     529     return compiled_fun(*args)
#
# ~/Documents/git_repos/paragami/venv/lib/python3.6/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     215
#     216   def memoized_fun(fun: WrappedFun, *args):
# --> 217     cache = fun_caches.setdefault(fun.f, {})
#     218     key = (fun.transforms, fun.params, args)
#     219     result = cache.get(key, None)
#
# /usr/lib/python3.6/weakref.py in setdefault(self, key, default)
#     483
#     484     def setdefault(self, key, default=None):
# --> 485         return self.data.setdefault(ref(key, self._remove),default)
#     486
#     487     def update(self, dict=None, **kwargs):
#
# TypeError: unhashable type: 'PSDSymmetricMatrixPattern'

# %%
ps = pstats.Stats(pr).strip_dirs().sort_stats('cumulative')
ps.print_stats()
# Out:
#          72208 function calls (72090 primitive calls) in 0.265 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         9    0.000    0.000    0.264    0.029 interactiveshell.py:3302(run_code)
#         9    0.000    0.000    0.264    0.029 {built-in method builtins.exec}
#   507/502    0.003    0.000    0.262    0.001 api.py:152(f_jitted)
#   508/502    0.001    0.000    0.249    0.000 core.py:1133(bind)
#   508/502    0.004    0.000    0.248    0.000 core.py:1113(call_bind)
#   507/502    0.001    0.000    0.237    0.000 xla.py:525(_xla_call_impl)
#   507/502    0.001    0.000    0.222    0.000 linear_util.py:216(memoized_fun)
#         2    0.000    0.000    0.217    0.108 xla.py:584(_xla_callable)
#         1    0.000    0.000    0.186    0.186 <ipython-input-16-6bfb3ea41ccc>:18(<module>)
#         1    0.156    0.156    0.156    0.156 xla.py:322(_backend_compile)
#         2    0.000    0.000    0.053    0.027 partial_eval.py:373(trace_to_jaxpr)
#         2    0.000    0.000    0.053    0.027 linear_util.py:137(call_wrapped)
#         1    0.001    0.001    0.046    0.046 <ipython-input-16-6bfb3ea41ccc>:21(<module>)
#         1    0.000    0.000    0.032    0.032 <ipython-input-16-6bfb3ea41ccc>:17(<module>)
#         1    0.000    0.000    0.031    0.031 <ipython-input-16-6bfb3ea41ccc>:14(<lambda>)
#         1    0.000    0.000    0.031    0.031 psdmatrix_patterns.py:295(flatten)
#       107    0.000    0.000    0.028    0.000 core.py:271(bind)
#         1    0.000    0.000    0.025    0.025 psdmatrix_patterns.py:141(_pack_posdef_matrix)
#         4    0.000    0.000    0.021    0.005 lax_numpy.py:3675(_index_to_gather)
#         1    0.000    0.000    0.020    0.020 <ipython-input-16-6bfb3ea41ccc>:15(<lambda>)
#         1    0.000    0.000    0.020    0.020 psdmatrix_patterns.py:305(fold)
#         1    0.000    0.000    0.020    0.020 psdmatrix_patterns.py:150(_unpack_posdef_matrix)
#        58    0.001    0.000    0.019    0.000 xla.py:222(apply_primitive)
#         3    0.000    0.000    0.017    0.006 scatter.py:265(index_update)
#         3    0.000    0.000    0.017    0.006 scatter.py:22(_scatter_update)
#        58    0.009    0.000    0.016    0.000 xla.py:327(_execute_compiled_primitive)
#         3    0.000    0.000    0.016    0.005 scatter.py:57(_scatter_impl)
#       639    0.001    0.000    0.016    0.000 xla.py:117(device_put)
#       502    0.002    0.000    0.013    0.000 xla.py:771(_execute_trivial)
#         5    0.000    0.000    0.012    0.002 lax_numpy.py:2739(diag)
#        12    0.000    0.000    0.010    0.001 lax_numpy.py:3700(<genexpr>)
#         1    0.000    0.000    0.009    0.009 psdmatrix_patterns.py:133(_log_matrix_diagonal)
#         8    0.000    0.000    0.009    0.001 lax_numpy.py:3426(_normalize_index)
# 1842/1832    0.007    0.000    0.009    0.000 util.py:29(safe_map)
#         1    0.000    0.000    0.009    0.009 psdmatrix_patterns.py:37(_vectorize_ld_matrix)
#       502    0.001    0.000    0.008    0.000 xla.py:777(<listcomp>)
#         1    0.000    0.000    0.008    0.008 psdmatrix_patterns.py:126(_exp_matrix_diagonal)
#         1    0.000    0.000    0.008    0.008 lax_numpy.py:3580(_rewriting_take)
#         1    0.000    0.000    0.008    0.008 lax_numpy.py:3591(_gather)
#         3    0.000    0.000    0.007    0.002 lax_numpy.py:2715(diagonal)
#         1    0.000    0.000    0.007    0.007 psdmatrix_patterns.py:68(_unvectorize_ld_matrix)
#        17    0.000    0.000    0.007    0.000 lax.py:639(broadcast_in_dim)
#        58    0.000    0.000    0.007    0.000 xla.py:329(<listcomp>)
#       502    0.006    0.000    0.006    0.000 xla.py:79(_device_put_unit)
#       101    0.000    0.000    0.006    0.000 xla.py:1149(_device_put_device_array)
#        11    0.000    0.000    0.006    0.001 lax.py:1359(full)
#       4/1    0.001    0.000    0.006    0.006 xla.py:371(jaxpr_subcomp)
#         1    0.000    0.000    0.006    0.006 psdmatrix_patterns.py:250(validate_folded)
#   677/667    0.002    0.000    0.005    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         8    0.000    0.000    0.005    0.001 lax.py:1628(full_like)
#       103    0.000    0.000    0.005    0.000 xla.py:1178(_force)
#         6    0.000    0.000    0.004    0.001 lax_numpy.py:2286(zeros_like)
#        28    0.000    0.000    0.004    0.000 lax.py:2998(_broadcast_in_dim_shape_rule)
#         5    0.000    0.000    0.004    0.001 lax_numpy.py:1364(where)
#       229    0.000    0.000    0.004    0.000 core.py:1064(canonicalize_shape)
#        69    0.000    0.000    0.004    0.000 lax.py:368(convert_element_type)
#        10    0.000    0.000    0.004    0.000 lax.py:298(add)
#         1    0.000    0.000    0.004    0.004 linalg.py:52(cholesky)
#        12    0.000    0.000    0.004    0.000 lax.py:621(broadcast)
#         4    0.000    0.000    0.004    0.001 lax_numpy.py:3743(<listcomp>)
#         1    0.000    0.000    0.004    0.004 lax_linalg.py:45(cholesky)
#         6    0.000    0.000    0.003    0.001 lax_numpy.py:4381(deferring_binary_op)
#         9    0.000    0.000    0.003    0.000 lax.py:693(select)
#        59    0.001    0.000    0.003    0.000 lax.py:5676(_check_shapelike)
#       237    0.001    0.000    0.003    0.000 dtypes.py:253(result_type)
#         9    0.000    0.000    0.003    0.000 lax.py:364(lt)
#        14    0.000    0.000    0.003    0.000 lax.py:2986(_broadcast_in_dim_impl)
#       507    0.002    0.000    0.003    0.000 api_util.py:87(donation_vector)
#        12    0.000    0.000    0.003    0.000 partial_eval.py:137(process_primitive)
#        12    0.000    0.000    0.003    0.000 partial_eval.py:143(default_process_primitive)
# 1160/1159    0.002    0.000    0.003    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.002    0.001 lax_numpy.py:2114(concatenate)
#       615    0.001    0.000    0.002    0.000 core.py:722(find_top_trace)
#         5    0.001    0.000    0.002    0.000 xla.py:756(_execute_compiled)
#      2405    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#       162    0.001    0.000    0.002    0.000 core.py:931(__init__)
#      1121    0.001    0.000    0.002    0.000 {built-in method builtins.next}
#         5    0.000    0.000    0.002    0.000 lax_numpy.py:1613(reduction)
#      1016    0.001    0.000    0.002    0.000 linear_util.py:185(transformation_with_aux)
#      1152    0.001    0.000    0.002    0.000 xla.py:158(abstractify)
#        10    0.000    0.000    0.002    0.000 lax.py:1863(standard_abstract_eval)
#        17    0.002    0.000    0.002    0.000 xla.py:1220(force_fun)
#       255    0.000    0.000    0.002    0.000 dtypes.py:248(dtype)
#         1    0.000    0.000    0.002    0.002 lax_numpy.py:2628(tril)
#        10    0.000    0.000    0.002    0.000 xla.py:1225(_device_put_impl)
#        13    0.000    0.000    0.002    0.000 lax_numpy.py:260(_promote_dtypes)
#         4    0.000    0.000    0.002    0.000 lax_numpy.py:2132(<listcomp>)
#         4    0.000    0.000    0.002    0.000 lax.py:433(concatenate)
#        45    0.000    0.000    0.002    0.000 core.py:802(concrete_aval)
#       627    0.000    0.000    0.002    0.000 xla.py:215(arg_spec)
#        14    0.001    0.000    0.002    0.000 source_info_util.py:27(user_frame)
#        20    0.000    0.000    0.002    0.000 lax_numpy.py:2280(asarray)
#         2    0.000    0.000    0.002    0.001 lax_numpy.py:2675(wrapper)
#        21    0.000    0.000    0.002    0.000 lax_numpy.py:2232(array)
#       518    0.001    0.000    0.002    0.000 contextlib.py:85(__exit__)
#       505    0.001    0.000    0.002    0.000 linear_util.py:131(populate_stores)
#       291    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(result_type)
#         6    0.000    0.000    0.002    0.000 partial_eval.py:430(trace_to_subjaxpr)
#      1558    0.002    0.000    0.002    0.000 {built-in method jaxlib.pytree.flatten}
#         6    0.000    0.000    0.002    0.000 {method 'send' of 'generator' objects}
#        17    0.002    0.000    0.002    0.000 xla.py:1217(force_fun)
#      1388    0.001    0.000    0.002    0.000 {built-in method builtins.getattr}
#       148    0.000    0.000    0.001    0.000 dtypes.py:145(issubdtype)
#         5    0.000    0.000    0.001    0.000 lax.py:1052(reduce)
#        15    0.000    0.000    0.001    0.000 lax_numpy.py:340(result_type)
#       507    0.001    0.000    0.001    0.000 linear_util.py:198(wrap_init)
#        45    0.000    0.000    0.001    0.000 core.py:992(__init__)
#         5    0.000    0.000    0.001    0.000 xla.py:758(<listcomp>)
#     18/13    0.000    0.000    0.001    0.000 xla_bridge.py:315(constant)
#       640    0.001    0.000    0.001    0.000 xla.py:136(canonicalize_dtype)
#         2    0.000    0.000    0.001    0.001 partial_eval.py:498(tracers_to_jaxpr)
#         1    0.000    0.000    0.001    0.001 lax_linalg.py:93(symmetrize)
#      1014    0.001    0.000    0.001    0.000 core.py:701(new_sublevel)
#        31    0.000    0.000    0.001    0.000 core.py:809(get_aval)
#         2    0.000    0.000    0.001    0.001 lax_numpy.py:361(fn)
#        15    0.000    0.000    0.001    0.000 xla.py:108(array_result_handler)
#         2    0.000    0.000    0.001    0.001 lax_numpy.py:2298(full)
#       101    0.001    0.000    0.001    0.000 xla.py:1154(_copy_device_array_to_device)
#         3    0.000    0.000    0.001    0.000 lax.py:977(scatter)
#        36    0.001    0.000    0.001    0.000 xla.py:124(_device_put_array)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:2869(matmul)
#       517    0.000    0.000    0.001    0.000 api.py:1643(_check_arg)
#        31    0.000    0.000    0.001    0.000 util.py:91(partial)
#       518    0.000    0.000    0.001    0.000 contextlib.py:79(__enter__)
#        14    0.000    0.000    0.001    0.000 core.py:1343(pp_eqn_compact)
#       175    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(shape)
#         2    0.000    0.000    0.001    0.001 lax_numpy.py:357(<lambda>)
#         3    0.000    0.000    0.001    0.000 lax.py:1655(slice_in_dim)
#         6    0.000    0.000    0.001    0.000 lax_numpy.py:2677(<genexpr>)
#      1024    0.000    0.000    0.001    0.000 tree_util.py:79(tree_structure)
#        31    0.000    0.000    0.001    0.000 functools.py:44(update_wrapper)
#      2028    0.001    0.000    0.001    0.000 linear_util.py:88(val)
#       518    0.000    0.000    0.001    0.000 contextlib.py:157(helper)
# 2474/2420    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#        13    0.000    0.000    0.001    0.000 xla_bridge.py:390(_ndarray_constant_handler)
#       513    0.000    0.000    0.001    0.000 tree_util.py:47(tree_flatten)
#         3    0.000    0.000    0.001    0.000 lax.py:700(slice)
#       114    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(ndim)
#      1016    0.000    0.000    0.001    0.000 linear_util.py:189(<lambda>)
#        11    0.000    0.000    0.001    0.000 xla.py:102(aval_to_result_handler)
#      1019    0.001    0.000    0.001    0.000 linear_util.py:126(wrap)
#        32    0.000    0.000    0.001    0.000 abstract_arrays.py:34(make_shaped_array)
#       151    0.000    0.000    0.001    0.000 numerictypes.py:365(issubdtype)
#       197    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#         5    0.000    0.000    0.001    0.000 lax_numpy.py:301(_promote_args)
#         2    0.000    0.000    0.001    0.000 xla.py:964(_forward_method)
#         2    0.001    0.000    0.001    0.000 xla.py:993(_value)
#         8    0.000    0.000    0.001    0.000 lax.py:1333(tie_in)
#       668    0.001    0.000    0.001    0.000 core.py:948(__hash__)
#        14    0.000    0.000    0.001    0.000 core.py:1405(pp_kv_pairs)
#       507    0.000    0.000    0.001    0.000 api.py:223(_jit_is_disabled)
#         1    0.000    0.000    0.001    0.001 lax.py:593(dot_general)
#        95    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.001    0.000 lax.py:678(pad)
#         4    0.000    0.000    0.001    0.000 lax.py:1381(_device_put_raw)
#       518    0.001    0.000    0.001    0.000 contextlib.py:59(__init__)
#         2    0.000    0.000    0.001    0.000 lax_numpy.py:2743(<lambda>)
#        18    0.000    0.000    0.001    0.000 fromnumeric.py:55(_wrapfunc)
#        32    0.000    0.000    0.001    0.000 dtypes.py:236(_dtype_priority)
#         1    0.000    0.000    0.001    0.001 xla.py:578(_xla_consts)
#      6406    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         8    0.000    0.000    0.001    0.000 lax.py:657(reshape)
#       510    0.001    0.000    0.001    0.000 util.py:23(safe_zip)
#         1    0.000    0.000    0.001    0.001 xla.py:580(<dictcomp>)
#        37    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(all)
#       515    0.000    0.000    0.001    0.000 api.py:1649(_valid_jaxtype)
#         2    0.000    0.000    0.001    0.000 lax.py:3901(_scatter_translation_rule)
#         5    0.000    0.000    0.001    0.000 xla.py:1141(_device_array_constant_handler)
#        52    0.000    0.000    0.001    0.000 fromnumeric.py:73(_wrapreduction)
#         3    0.000    0.000    0.001    0.000 lax.py:1107(_reduce_sum)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:2311(zeros)
#         4    0.000    0.000    0.001    0.000 lax_numpy.py:3635(_split_index_for_jit)
#         1    0.000    0.000    0.001    0.001 core.py:481(__add__)
#       572    0.000    0.000    0.001    0.000 config.py:59(read)
#       509    0.001    0.000    0.001    0.000 tree_util.py:59(tree_unflatten)
#       631    0.000    0.000    0.001    0.000 core.py:723(<genexpr>)
#         7    0.000    0.000    0.001    0.000 lax.py:5379(_tie_in_impl)
#       507    0.000    0.000    0.001    0.000 weakref.py:484(setdefault)
#        37    0.000    0.000    0.001    0.000 fromnumeric.py:2324(all)
#        14    0.000    0.000    0.001    0.000 core.py:797(check_valid_jaxtype)
#         1    0.000    0.000    0.001    0.001 core.py:1136(process)
#         1    0.000    0.000    0.001    0.001 partial_eval.py:166(process_call)
#         4    0.000    0.000    0.001    0.000 lax_numpy.py:3887(_expand_bool_indices)
#     70/69    0.000    0.000    0.001    0.000 core.py:529(__getattr__)
#        14    0.000    0.000    0.001    0.000 core.py:789(valid_jaxtype)
#        44    0.000    0.000    0.001    0.000 core.py:1045(raise_to_shaped)
#       302    0.000    0.000    0.001    0.000 numerictypes.py:293(issubclass_)
#       510    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#        31    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.001    0.001 <ipython-input-16-6bfb3ea41ccc>:15(<module>)
#        76    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        12    0.000    0.000    0.001    0.000 lax_numpy.py:3698(<genexpr>)
#         9    0.000    0.000    0.001    0.000 codeop.py:132(__call__)
#         1    0.000    0.000    0.001    0.001 lax.py:2774(_dot_general_shape_rule)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:478(true_divide)
#         1    0.000    0.000    0.001    0.001 xla.py:827(_xla_call_translation_rule)
#       616    0.000    0.000    0.001    0.000 {built-in method builtins.issubclass}
#       622    0.001    0.000    0.001    0.000 xla_bridge.py:173(get_device_backend)
#        49    0.000    0.000    0.001    0.000 lazy.py:112(array)
#        15    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(take)
#         2    0.001    0.000    0.001    0.000 weakref.py:356(remove)
#        36    0.000    0.000    0.001    0.000 xla.py:145(_canonicalize_ndarray_dtype)
#       101    0.000    0.000    0.001    0.000 _asarray.py:16(asarray)
#         9    0.000    0.000    0.001    0.000 core.py:1407(<listcomp>)
#         2    0.000    0.000    0.001    0.000 twodim_base.py:790(tril_indices)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:1189(expand_dims)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:411(fn)
#         9    0.001    0.000    0.001    0.000 {built-in method builtins.compile}
#        13    0.000    0.000    0.001    0.000 xla_bridge.py:297(_numpy_array_constant)
#         1    0.000    0.000    0.001    0.001 lax.py:3266(expand_dims)
#       569    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        23    0.000    0.000    0.000    0.000 core.py:1402(pp_kv_pair)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(insert)
#       106    0.000    0.000    0.000    0.000 pprint_util.py:53(pp)
#         2    0.000    0.000    0.000    0.000 lax_numpy.py:346(fn)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:97(take)
#        43    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 function_base.py:4429(insert)
#      1526    0.000    0.000    0.000    0.000 linear_util.py:116(__init__)
#        69    0.000    0.000    0.000    0.000 pprint_util.py:36(__rshift__)
#        13    0.000    0.000    0.000    0.000 partial_eval.py:489(recipe_to_eqn)
#        13    0.000    0.000    0.000    0.000 lax_numpy.py:267(<listcomp>)
#         8    0.000    0.000    0.000    0.000 lax.py:3278(_reshape_impl)
#       114    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#        29    0.000    0.000    0.000    0.000 lax_numpy.py:330(issubdtype)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:2372(arange)
#         1    0.000    0.000    0.000    0.000 lax.py:344(eq)
#       108    0.000    0.000    0.000    0.000 lazy.py:143(is_trivial)
#       681    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       175    0.000    0.000    0.000    0.000 fromnumeric.py:1903(shape)
#       522    0.000    0.000    0.000    0.000 core.py:716(full_lower)
#        43    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         2    0.000    0.000    0.000    0.000 lax.py:4316(_reduction_computation)
#         5    0.000    0.000    0.000    0.000 lax.py:1073(_get_monoid_reducer)
#         7    0.000    0.000    0.000    0.000 lax.py:1029(transpose)
#        39    0.000    0.000    0.000    0.000 partial_eval.py:515(getvar)
#        49    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       509    0.000    0.000    0.000    0.000 linear_util.py:122(__name__)
#         1    0.000    0.000    0.000    0.000 lax.py:310(div)
#         5    0.000    0.000    0.000    0.000 lax_numpy.py:2349(eye)
#         2    0.000    0.000    0.000    0.000 util.py:121(toposort)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#         2    0.000    0.000    0.000    0.000 lax_numpy.py:920(transpose)
#         4    0.000    0.000    0.000    0.000 xla.py:77(_make_unit)
#        19    0.000    0.000    0.000    0.000 partial_eval.py:119(instantiate_const)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1804(nonzero)
#         1    0.000    0.000    0.000    0.000 lax.py:783(gather)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:42(_wrapit)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:275(partial_eval)
#       162    0.000    0.000    0.000    0.000 core.py:870(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 core.py:207(<lambda>)
#      2028    0.000    0.000    0.000    0.000 linear_util.py:94(__nonzero__)
#       242    0.000    0.000    0.000    0.000 xla.py:979(__init__)
#        65    0.000    0.000    0.000    0.000 config.py:134(__getattr__)
#        21    0.000    0.000    0.000    0.000 lax_numpy.py:2275(_can_call_numpy_array)
#        16    0.000    0.000    0.000    0.000 lax_numpy.py:313(_constant_like)
#         1    0.000    0.000    0.000    0.000 lax.py:302(sub)
#       509    0.000    0.000    0.000    0.000 core.py:612(next_level)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#        13    0.000    0.000    0.000    0.000 partial_eval.py:494(<listcomp>)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(delete)
#        13    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.ConstantLiteral}
#         5    0.000    0.000    0.000    0.000 lazy.py:196(stage_lexpr)
#        20    0.000    0.000    0.000    0.000 core.py:168(__init__)
#         3    0.000    0.000    0.000    0.000 function_base.py:4218(delete)
#         5    0.000    0.000    0.000    0.000 partial_eval.py:527(getconstvar)
#       502    0.000    0.000    0.000    0.000 xla.py:775(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:3494(_slice_shape_rule)
#         8    0.000    0.000    0.000    0.000 abstract_arrays.py:65(_make_concrete_python_scalar)
#       256    0.000    0.000    0.000    0.000 core.py:1058(_canonicalize_dimension)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:2236(any)
#       572    0.000    0.000    0.000    0.000 config.py:72(check_exists)
#         6    0.000    0.000    0.000    0.000 xla.py:356(prefetch)
#         5    0.000    0.000    0.000    0.000 xla.py:1024(copy_to_host_async)
#       103    0.000    0.000    0.000    0.000 partial_eval.py:351(aval)
#         1    0.000    0.000    0.000    0.000 lax.py:1122(_reduce_and)
#      1608    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 lax.py:150(log)
#      1016    0.000    0.000    0.000    0.000 linear_util.py:83(store)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3918(_is_advanced_int_indexer)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(moveaxis)
#      1016    0.000    0.000    0.000    0.000 linear_util.py:80(__init__)
#        13    0.000    0.000    0.000    0.000 xla_bridge.py:289(normalize_to_xla_dtypes)
#         4    0.000    0.000    0.000    0.000 partial_eval.py:109(new_instantiated_const)
#         5    0.000    0.000    0.000    0.000 lax.py:1407(_eye)
#         2    0.000    0.000    0.000    0.000 lax.py:1902(naryop_dtype_rule)
#       120    0.000    0.000    0.000    0.000 core.py:943(__eq__)
#       508    0.000    0.000    0.000    0.000 core.py:1088(apply_todos)
#        28    0.000    0.000    0.000    0.000 source_info_util.py:30(<genexpr>)
#         8    0.000    0.000    0.000    0.000 typing.py:1156(__instancecheck__)
#       507    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       560    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 numeric.py:1340(moveaxis)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:306(_promote_args_inexact)
#         1    0.000    0.000    0.000    0.000 lax.py:4353(_reduce_sum_translation_rule)
#      1067    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 function_base.py:1141(diff)
#         8    0.000    0.000    0.000    0.000 lax_numpy.py:214(_np_array)
#         3    0.000    0.000    0.000    0.000 lax.py:5888(_abstractify)
#       148    0.000    0.000    0.000    0.000 dtypes.py:134(_issubclass)
#         1    0.000    0.000    0.000    0.000 lax.py:1915(_broadcasting_shape_rule)
#        59    0.000    0.000    0.000    0.000 lazy.py:38(__new__)
#         2    0.000    0.000    0.000    0.000 twodim_base.py:348(tri)
#        64    0.000    0.000    0.000    0.000 pprint_util.py:25(indent)
#         5    0.000    0.000    0.000    0.000 lax.py:1877(standard_translate)
#         8    0.000    0.000    0.000    0.000 typing.py:1145(__subclasscheck__)
#       214    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9d12c0}
#         4    0.000    0.000    0.000    0.000 lax.py:1388(iota)
#        21    0.000    0.000    0.000    0.000 tree_util.py:75(tree_leaves)
#         1    0.000    0.000    0.000    0.000 lax.py:142(exp)
#        13    0.000    0.000    0.000    0.000 partial_eval.py:463(new_eqn_recipe)
#        12    0.000    0.000    0.000    0.000 lax_numpy.py:3924(<genexpr>)
#        18    0.000    0.000    0.000    0.000 lazy.py:129(broadcast)
#         1    0.000    0.000    0.000    0.000 lax.py:62(_try_broadcast_shapes)
#         1    0.000    0.000    0.000    0.000 lax.py:1119(_reduce_or)
#       118    0.000    0.000    0.000    0.000 partial_eval.py:77(get_aval)
#         6    0.000    0.000    0.000    0.000 lax_numpy.py:230(_promote_shapes)
#        24    0.000    0.000    0.000    0.000 core.py:372(full_raise)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:269(_promote_dtypes_inexact)
#         1    0.000    0.000    0.000    0.000 lax.py:4350(_reduce_sum_shape_rule)
#         8    0.000    0.000    0.000    0.000 xla_bridge.py:302(parameter)
#        18    0.000    0.000    0.000    0.000 lax.py:1905(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:4377(_reduce_op_shape_rule)
#        60    0.000    0.000    0.000    0.000 lax.py:5892(_check_user_dtype_supported)
#         2    0.000    0.000    0.000    0.000 util.py:152(check_toposort)
#         7    0.000    0.000    0.000    0.000 lax_numpy.py:292(_check_arraylike)
#         1    0.000    0.000    0.000    0.000 lax_linalg.py:92(_H)
#        13    0.000    0.000    0.000    0.000 source_info_util.py:49(current)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:1412(broadcast_arrays)
#        15    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#       6/3    0.000    0.000    0.000    0.000 xla.py:361(jaxpr_literals)
#         8    0.000    0.000    0.000    0.000 lax_numpy.py:3927(_is_int_arraylike)
#         3    0.000    0.000    0.000    0.000 lax.py:2776(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:2841(_dot_general_dtype_rule)
#         2    0.000    0.000    0.000    0.000 api.py:92(jit)
#       666    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        29    0.000    0.000    0.000    0.000 xla.py:374(read)
#        86    0.000    0.000    0.000    0.000 xla.py:1016(ndim)
#         8    0.000    0.000    0.000    0.000 abc.py:196(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:1422(broadcast_to)
#         5    0.000    0.000    0.000    0.000 lax_numpy.py:1651(_reduction_init_val)
#       113    0.000    0.000    0.000    0.000 xla.py:1133(is_device_constant)
#       603    0.000    0.000    0.000    0.000 xla.py:72(identity)
#         1    0.000    0.000    0.000    0.000 lax_linalg.py:91(_T)
#         2    0.000    0.000    0.000    0.000 lax.py:3377(_transpose_impl)
#         1    0.000    0.000    0.000    0.000 <ipython-input-16-6bfb3ea41ccc>:26(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:1196(swapaxes)
#         5    0.000    0.000    0.000    0.000 lax.py:3219(squeeze)
#         3    0.000    0.000    0.000    0.000 partial_eval.py:129(instantiate_const_abstracted)
#         1    0.000    0.000    0.000    0.000 <ipython-input-16-6bfb3ea41ccc>:14(<module>)
#        38    0.000    0.000    0.000    0.000 lax_numpy.py:107(__instancecheck__)
#         9    0.000    0.000    0.000    0.000 pprint_util.py:59(vcat)
#        45    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#        21    0.000    0.000    0.000    0.000 lax_numpy.py:294(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Scatter}
#         8    0.000    0.000    0.000    0.000 core.py:99(subjaxprs)
#       162    0.000    0.000    0.000    0.000 xla.py:1008(dtype)
#         5    0.000    0.000    0.000    0.000 numeric.py:159(ones)
#         2    0.000    0.000    0.000    0.000 iostream.py:386(write)
#       175    0.000    0.000    0.000    0.000 fromnumeric.py:1899(_shape_dispatcher)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:1179(squeeze)
#         7    0.000    0.000    0.000    0.000 partial_eval.py:92(pure)
#       257    0.000    0.000    0.000    0.000 pprint_util.py:22(__init__)
#         6    0.000    0.000    0.000    0.000 lax_numpy.py:235(<listcomp>)
#         2    0.000    0.000    0.000    0.000 xla.py:1312(_pval_to_result_handler)
#       136    0.000    0.000    0.000    0.000 xla.py:1004(shape)
#        20    0.000    0.000    0.000    0.000 partial_eval.py:66(unknown)
#        14    0.000    0.000    0.000    0.000 pprint_util.py:49(__str__)
#         8    0.000    0.000    0.000    0.000 numeric.py:1277(normalize_axis_tuple)
#        13    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.get_traceback}
#         8    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Parameter}
#         3    0.000    0.000    0.000    0.000 lax.py:2783(<genexpr>)
#         1    0.000    0.000    0.000    0.000 xla.py:716(_xla_callable_args)
#        19    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 lax_numpy.py:1639(_reduction_dims)
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         8    0.000    0.000    0.000    0.000 lax.py:3289(_is_singleton_reshape)
#         4    0.000    0.000    0.000    0.000 core.py:856(concrete_or_error)
#        14    0.000    0.000    0.000    0.000 lax_numpy.py:291(_arraylike)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2194(atleast_1d)
#        17    0.000    0.000    0.000    0.000 core.py:89(jaxprs_in_params)
#         3    0.000    0.000    0.000    0.000 iostream.py:197(schedule)
#         1    0.000    0.000    0.000    0.000 linalg.py:39(_promote_arg_dtypes)
#         7    0.000    0.000    0.000    0.000 partial_eval.py:101(new_const)
#       502    0.000    0.000    0.000    0.000 xla.py:1316(<lambda>)
#        28    0.000    0.000    0.000    0.000 partial_eval.py:337(__init__)
#         2    0.000    0.000    0.000    0.000 util.py:98(__get__)
#        14    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#       291    0.000    0.000    0.000    0.000 multiarray.py:635(result_type)
#         3    0.000    0.000    0.000    0.000 _dtype.py:46(__str__)
#         1    0.000    0.000    0.000    0.000 lax.py:2938(_dot_general_translation_rule)
#         1    0.000    0.000    0.000    0.000 xla.py:728(<listcomp>)
#        63    0.000    0.000    0.000    0.000 partial_eval.py:355(parents)
#       175    0.000    0.000    0.000    0.000 partial_eval.py:73(get_known)
#        42    0.000    0.000    0.000    0.000 lax_numpy.py:2276(<genexpr>)
#         3    0.000    0.000    0.000    0.000 lax.py:5720(_const)
#        19    0.000    0.000    0.000    0.000 dtypes.py:209(promote_types)
#        28    0.000    0.000    0.000    0.000 partial_eval.py:51(__new__)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:1414(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:3385(_transpose_shape_rule)
#         2    0.000    0.000    0.000    0.000 {method 'outer' of 'numpy.ufunc' objects}
#        38    0.000    0.000    0.000    0.000 lax.py:3015(<genexpr>)
#         2    0.000    0.000    0.000    0.000 lax.py:3892(_scatter_dtype_rule)
#         1    0.000    0.000    0.000    0.000 lax.py:2388(_convert_element_type_translation_rule)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:106(new_instantiated_literal)
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.000    0.000 xla.py:832(<listcomp>)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3934(_canonicalize_tuple_index)
#       3/2    0.000    0.000    0.000    0.000 xla.py:475(jaxpr_replicas)
#         3    0.000    0.000    0.000    0.000 _dtype.py:333(_name_get)
#        12    0.000    0.000    0.000    0.000 partial_eval.py:150(<listcomp>)
#        37    0.000    0.000    0.000    0.000 dtypes.py:230(is_python_scalar)
#         4    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         3    0.000    0.000    0.000    0.000 socket.py:357(send)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Call}
#        14    0.000    0.000    0.000    0.000 core.py:1344(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 dtypes.py:263(<listcomp>)
#         4    0.000    0.000    0.000    0.000 xla_bridge.py:381(make_computation_builder)
#        13    0.000    0.000    0.000    0.000 partial_eval.py:493(<listcomp>)
#        52    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3660(_merge_static_and_dynamic_indices)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:277(_to_inexact_dtype)
#        64    0.000    0.000    0.000    0.000 pprint_util.py:26(<listcomp>)
#       144    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       209    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Reduce}
#         5    0.000    0.000    0.000    0.000 lazy.py:118(eye)
#         4    0.000    0.000    0.000    0.000 twodim_base.py:33(_min_int)
#         1    0.000    0.000    0.000    0.000 xla.py:746(_xla_param)
#       106    0.000    0.000    0.000    0.000 pprint_util.py:54(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Add}
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2620(tri)
#         4    0.000    0.000    0.000    0.000 core.py:683(new_master)
#         9    0.000    0.000    0.000    0.000 traitlets.py:545(__get__)
#       106    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 lax.py:5591(_check_same_dtypes)
#        18    0.000    0.000    0.000    0.000 compilerop.py:138(extra_flags)
#         6    0.000    0.000    0.000    0.000 api_util.py:41(flatten_fun)
#         1    0.000    0.000    0.000    0.000 lax.py:1091(_get_max_identity)
#        84    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        13    0.000    0.000    0.000    0.000 core.py:156(new_jaxpr_eqn)
#       114    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#         8    0.000    0.000    0.000    0.000 lax_numpy.py:3922(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:1099(_get_min_identity)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:274(<listcomp>)
#         2    0.000    0.000    0.000    0.000 lazy.py:135(transpose)
#     17/15    0.000    0.000    0.000    0.000 xla.py:481(<genexpr>)
#         2    0.000    0.000    0.000    0.000 xla.py:696(_xla_callable_device)
#        30    0.000    0.000    0.000    0.000 core.py:935(<lambda>)
#         9    0.000    0.000    0.000    0.000 util.py:36(unzip2)
#        18    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:1416(<listcomp>)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:65(get_compile_options)
#         2    0.000    0.000    0.000    0.000 api_util.py:27(wraps)
#         1    0.000    0.000    0.000    0.000 linalg.py:43(<listcomp>)
#        13    0.000    0.000    0.000    0.000 lax.py:5908(_canonicalize_axis)
#         1    0.000    0.000    0.000    0.000 lax.py:1432(_tri)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.BroadcastInDim}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amax)
#         9    0.000    0.000    0.000    0.000 traitlets.py:526(get)
#         1    0.000    0.000    0.000    0.000 lax.py:1882(unop_dtype_rule)
#         1    0.000    0.000    0.000    0.000 __init__.py:525(log)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         7    0.000    0.000    0.000    0.000 partial_eval.py:62(known)
#        23    0.000    0.000    0.000    0.000 pprint_util.py:33(__add__)
#     14/13    0.000    0.000    0.000    0.000 xla.py:485(eqn_replicas)
#         3    0.000    0.000    0.000    0.000 _dtype.py:319(_name_includes_bit_suffix)
#        12    0.000    0.000    0.000    0.000 partial_eval.py:146(<listcomp>)
#         1    0.000    0.000    0.000    0.000 xla_client.py:206(dtype_to_etype)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.DotGeneral}
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Tuple}
#         2    0.000    0.000    0.000    0.000 lax.py:3881(_scatter_dimensions_proto)
#         4    0.000    0.000    0.000    0.000 lazy.py:115(iota)
#         2    0.000    0.000    0.000    0.000 xla.py:596(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:112(new_arg)
#         6    0.000    0.000    0.000    0.000 core.py:1094(process_env_traces)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2551(amax)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.array_shape}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:997(argsort)
#        26    0.000    0.000    0.000    0.000 lax.py:1864(<genexpr>)
#         3    0.000    0.000    0.000    0.000 lax.py:1883(<genexpr>)
#         3    0.000    0.000    0.000    0.000 masking.py:116(is_polymorphic)
#         1    0.000    0.000    0.000    0.000 xla.py:432(xla_destructure)
#        14    0.000    0.000    0.000    0.000 partial_eval.py:362(full_lower)
#        15    0.000    0.000    0.000    0.000 core.py:367(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 lax_numpy.py:138(__hash__)
#        15    0.000    0.000    0.000    0.000 core.py:680(cur_sublevel)
#         4    0.000    0.000    0.000    0.000 getlimits.py:508(min)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(where)
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:117(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.ConvertElementType}
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Transpose}
#        13    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         5    0.000    0.000    0.000    0.000 xla.py:761(<listcomp>)
#         9    0.000    0.000    0.000    0.000 hooks.py:103(__call__)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Select}
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:269(host_count)
#         6    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 lax.py:3536(_slice_translation_rule)
#         1    0.000    0.000    0.000    0.000 xla.py:318(primitive_subcomputation)
#         1    0.000    0.000    0.000    0.000 xla.py:90(aval_to_xla_shape)
#        42    0.000    0.000    0.000    0.000 pprint_util.py:50(<genexpr>)
#        31    0.000    0.000    0.000    0.000 xla.py:386(write)
#        43    0.000    0.000    0.000    0.000 util.py:155(<genexpr>)
#        14    0.000    0.000    0.000    0.000 xla_client.py:156(__init__)
#         8    0.000    0.000    0.000    0.000 numeric.py:1327(<listcomp>)
#         8    0.000    0.000    0.000    0.000 typing.py:1033(_abc_negative_cache_version)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Iota}
#         1    0.000    0.000    0.000    0.000 linalg.py:41(_to_inexact_type)
#         1    0.000    0.000    0.000    0.000 linalg.py:45(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:5386(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax.py:4344(_reduce_number_dtype_rule)
#         2    0.000    0.000    0.000    0.000 xla.py:270(_device_from_arg_devices)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:227(<listcomp>)
#         1    0.000    0.000    0.000    0.000 numeric.py:1786(isscalar)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#         2    0.000    0.000    0.000    0.000 api.py:80(_check_callable)
#         2    0.000    0.000    0.000    0.000 <string>:31(__repr__)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:264(host_ids)
#        26    0.000    0.000    0.000    0.000 partial_eval.py:147(<genexpr>)
#         1    0.000    0.000    0.000    0.000 xla.py:83(_make_array_shape)
#        15    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Slice}
#         1    0.000    0.000    0.000    0.000 xla.py:798(_xla_call_partial_eval_update_params)
#        27    0.000    0.000    0.000    0.000 xla.py:1129(__init__)
#        27    0.000    0.000    0.000    0.000 partial_eval.py:70(is_known)
#         3    0.000    0.000    0.000    0.000 linear_util.py:175(transformation)
#         1    0.000    0.000    0.000    0.000 __init__.py:1102(log)
#        37    0.000    0.000    0.000    0.000 fromnumeric.py:2320(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:964(conjugate)
#        12    0.000    0.000    0.000    0.000 lax.py:1878(<genexpr>)
#         2    0.000    0.000    0.000    0.000 util.py:158(_remove_duplicates)
#         9    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Eq}
#         4    0.000    0.000    0.000    0.000 lax.py:5601(<setcomp>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(iscomplexobj)
#         8    0.000    0.000    0.000    0.000 typing.py:1019(_abc_negative_cache)
#         6    0.000    0.000    0.000    0.000 lax_numpy.py:236(<listcomp>)
#         1    0.000    0.000    0.000    0.000 xla.py:434(<listcomp>)
#         2    0.000    0.000    0.000    0.000 core.py:194(gensym)
#         2    0.000    0.000    0.000    0.000 inspect.py:172(isgeneratorfunction)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.Exp}
#        12    0.000    0.000    0.000    0.000 lax_numpy.py:3936(<genexpr>)
#         2    0.000    0.000    0.000    0.000 lax_numpy.py:334(isscalar)
#        13    0.000    0.000    0.000    0.000 partial_eval.py:492(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1359(log)
#        36    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        28    0.000    0.000    0.000    0.000 {method 'issubset' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 lax_numpy.py:141(__eq__)
#         5    0.000    0.000    0.000    0.000 lax.py:1851(<lambda>)
#         1    0.000    0.000    0.000    0.000 xla_client.py:488(make_dot_dimension_numbers)
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:323(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 abc.py:180(__instancecheck__)
#         7    0.000    0.000    0.000    0.000 {method 'capitalize' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 base_patterns.py:193(flat_length)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3714(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:1919(<setcomp>)
#         1    0.000    0.000    0.000    0.000 xla.py:148(_canonicalize_python_scalar_dtype)
#         2    0.000    0.000    0.000    0.000 core.py:67(__init__)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3696(<listcomp>)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3872(_eliminate_deprecated_list_indexing)
#         2    0.000    0.000    0.000    0.000 api_util.py:96(rebase_donate_argnums)
#         2    0.000    0.000    0.000    0.000 core.py:624(pop)
#         5    0.000    0.000    0.000    0.000 util.py:191(prod)
#         4    0.000    0.000    0.000    0.000 getlimits.py:521(max)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:93(_take_dispatcher)
#         2    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.ops.GetTupleElement}
#         1    0.000    0.000    0.000    0.000 psdmatrix_patterns.py:242(_validate_folded_shape)
#         1    0.000    0.000    0.000    0.000 lazy.py:122(tri)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:768(_zip_knowns)
#         1    0.000    0.000    0.000    0.000 xla.py:436(check_backend_params)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:179(device_count)
#         2    0.000    0.000    0.000    0.000 core.py:618(push)
#         3    0.000    0.000    0.000    0.000 core.py:936(<lambda>)
#         4    0.000    0.000    0.000    0.000 api.py:2008(_ensure_tuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:1544(isEnabledFor)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 xla.py:579(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 xla.py:947(_check_if_deleted)
#         4    0.000    0.000    0.000    0.000 partial_eval.py:200(<genexpr>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:210(<listcomp>)
#         1    0.000    0.000    0.000    0.000 util.py:72(split_list)
#         1    0.000    0.000    0.000    0.000 type_check.py:280(iscomplexobj)
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:1276(user_global_ns)
#         2    0.000    0.000    0.000    0.000 inspect.py:159(isfunction)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:3940(<genexpr>)
#         6    0.000    0.000    0.000    0.000 lazy.py:137(<genexpr>)
#         1    0.000    0.000    0.000    0.000 xla.py:582(<listcomp>)
#         4    0.000    0.000    0.000    0.000 api_util.py:37(get_name)
#         1    0.000    0.000    0.000    0.000 xla_bridge.py:202(devices)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:433(<listcomp>)
#         2    0.000    0.000    0.000    0.000 xla_client.py:641(__init__)
#         2    0.000    0.000    0.000    0.000 core.py:590(__init__)
#         2    0.000    0.000    0.000    0.000 core.py:1101(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-16-6bfb3ea41ccc>:20(<module>)
#         4    0.000    0.000    0.000    0.000 numeric.py:1403(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:2723(<listcomp>)
#         2    0.000    0.000    0.000    0.000 lax.py:1903(<listcomp>)
#         6    0.000    0.000    0.000    0.000 lazy.py:136(<genexpr>)
#         3    0.000    0.000    0.000    0.000 masking.py:117(<lambda>)
#         1    0.000    0.000    0.000    0.000 xla.py:444(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 xla_bridge.py:266(<genexpr>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:212(<listcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:228(__init__)
#         1    0.000    0.000    0.000    0.000 core.py:600(__eq__)
#         2    0.000    0.000    0.000    0.000 util.py:138(<listcomp>)
#         2    0.000    0.000    0.000    0.000 util.py:240(wrap_name)
#         1    0.000    0.000    0.000    0.000 <ipython-input-16-6bfb3ea41ccc>:28(<module>)
#         4    0.000    0.000    0.000    0.000 function_base.py:4425(_insert_dispatcher)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:2232(_any_dispatcher)
#         3    0.000    0.000    0.000    0.000 _dtype.py:36(_kind_name)
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         9    0.000    0.000    0.000    0.000 hooks.py:168(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#        14    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         3    0.000    0.000    0.000    0.000 base_patterns.py:160(_free_with_default)
#         1    0.000    0.000    0.000    0.000 lax.py:1899(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax.py:2382(_convert_element_type_shape_rule)
#         5    0.000    0.000    0.000    0.000 lax.py:3222(<genexpr>)
#         4    0.000    0.000    0.000    0.000 lazy.py:245(<genexpr>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:770(<listcomp>)
#         2    0.000    0.000    0.000    0.000 xla.py:181(apply_outfeed_rewriter)
#         1    0.000    0.000    0.000    0.000 xla.py:806(<listcomp>)
#         1    0.000    0.000    0.000    0.000 xla.py:1012(size)
#         2    0.000    0.000    0.000    0.000 api_util.py:38(get_module)
#         2    0.000    0.000    0.000    0.000 api_util.py:39(get_doc)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:201(<genexpr>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:441(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:445(instantiate_const_at)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:540(<genexpr>)
#         1    0.000    0.000    0.000    0.000 converter.py:138(absl_to_standard)
#         1    0.000    0.000    0.000    0.000 xla_client.py:481(__init__)
#         2    0.000    0.000    0.000    0.000 util.py:243(extend_name_stack)
#         3    0.000    0.000    0.000    0.000 function_base.py:4214(_delete_dispatcher)
#         4    0.000    0.000    0.000    0.000 numeric.py:1336(_moveaxis_dispatcher)
#         2    0.000    0.000    0.000    0.000 multiarray.py:312(where)
#        13    0.000    0.000    0.000    0.000 typing.py:1432(cast)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 lax.py:1916(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:2766(_precision_config)
#         1    0.000    0.000    0.000    0.000 lax.py:3269(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:3273(<listcomp>)
#         2    0.000    0.000    0.000    0.000 lax.py:3898(_scatter_shape_rule)
#         2    0.000    0.000    0.000    0.000 lax.py:615(<lambda>)
#         2    0.000    0.000    0.000    0.000 lax.py:616(<lambda>)
#         3    0.000    0.000    0.000    0.000 xla.py:171(<lambda>)
#         1    0.000    0.000    0.000    0.000 xla.py:1240(<lambda>)
#         1    0.000    0.000    0.000    0.000 xla.py:1242(<lambda>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:175(<listcomp>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:206(<listcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:597(__hash__)
#         4    0.000    0.000    0.000    0.000 function_base.py:1137(_diff_dispatcher)
#         1    0.000    0.000    0.000    0.000 type_check.py:207(_is_type_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:993(_argsort_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1800(_nonzero_dispatcher)
#         5    0.000    0.000    0.000    0.000 multiarray.py:1043(copyto)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:3244(compare)
#         1    0.000    0.000    0.000    0.000 lax.py:5387(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax.py:5752(_canonicalize_precision)
#         1    0.000    0.000    0.000    0.000 lax.py:2385(_convert_element_type_dtype_rule)
#         1    0.000    0.000    0.000    0.000 lax.py:83(_identity)
#         2    0.000    0.000    0.000    0.000 xla.py:281(<genexpr>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2546(_amax_dispatcher)
#         1    0.000    0.000    0.000    0.000 multiarray.py:145(concatenate)
#         3    0.000    0.000    0.000    0.000 multiarray.py:469(can_cast)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)

# %%
empty_val = pattern.empty(valid=False)


random_val = pattern.random()
pattern.flatten(random_val, free=False)

str(pattern)

pattern.empty_bool(True)

# Make sure to test != using a custom test.
testcase.assertTrue(pattern == pattern)




###############################
# Test folding and unfolding.
for free in [True, False, None]:
    for free_default in [True, False, None]:
        pattern.free_default = free_default
        if (free_default is None) and (free is None):
            with testcase.assertRaises(ValueError):
                flat_val = pattern.flatten(valid_value, free=free)
            with testcase.assertRaises(ValueError):
                folded_val = pattern.fold(flat_val, free=free)
        else:
            flat_val = pattern.flatten(valid_value, free=free)
            testcase.assertEqual(len(flat_val), pattern.flat_length(free))
            folded_val = pattern.fold(flat_val, free=free)
            check_equal(valid_value, folded_val)
            if hasattr(valid_value, 'shape'):
                testcase.assertEqual(valid_value.shape, folded_val.shape)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# # Generic Jax stuff

# %%
x = onp.random.random(100)
mu = onp.random.random(100)

# I would have expected this to get rid of the annoying warning but it does not.
cpu_device = jax.devices('cpu')[0]
jax.device_put(x, cpu_device);
jax.device_put(mu, cpu_device);

# %%
g = grad_fun(mu, x)
h = hess_fun(mu, x)
print(np.max(np.abs(g - (mu - x))))
print(np.max(np.abs(h - np.eye(100))))

# %%
# https://jax.readthedocs.io/en/latest/notebooks/Custom_derivative_rules_for_Python_code.html

# %%
from jax import custom_jvp
import jax.numpy as jnp

# f :: a -> b
@custom_jvp
def f(x):
    return jnp.sin(x)

# f_jvp :: (a, T a) -> (b, T b)
def f_jvp(primals, tangents):
    x, = primals
    t, = tangents
    return f(x), jnp.cos(x) * t

f.defjvp(f_jvp)

print(type(f(0.5)))

print('Use jax')
foo = jax.numpy.asarray(f(0.5) + 3)
print(foo, type(foo))
print(isinstance(foo, onp.ndarray))
print(isinstance(foo, jax.numpy.ndarray))

print('Use numpy')
foo = onp.asarray(f(0.5) + 3)
print(isinstance(foo, onp.ndarray))
print(isinstance(foo, jax.numpy.ndarray))

# %%
@custom_jvp
def f(x, y):
    return jnp.sin(x) * y

f.defjvps(lambda x_dot, primal_out, x, y: jnp.cos(x) * x_dot * y,
          lambda y_dot, primal_out, x, y: jnp.sin(x) * y_dot)

# %%
foo = np.array([1, 2, 3])
print(jax.ops.index_update(foo, [1, 2], [10, 20]))

foo = np.array([[1, 2], [3, 4]])
print(jax.ops.index_update(foo, [1, 2], [10, 20]))

inds = np.triu_indices(2)
print(inds)
print(jax.ops.index_update(foo, inds, [10, 20, 30]))

# %%
#jax.sp.logsumexp

# %%
vec = np.arange(0, 3, dtype=np.float32) + 1
np.diag(vec)

# %%
def _exp_matrix_diagonal(mat):
    assert mat.shape[0] == mat.shape[1]
    dim = mat.shape[0]
    diag_inds = (np.arange(dim), np.arange(dim))
    exp_diags = np.exp(np.diag(mat))
    return(jax.ops.index_update(mat, diag_inds, exp_diags))

def _log_matrix_diagonal(mat):
    assert mat.shape[0] == mat.shape[1]
    dim = mat.shape[0]
    diag_inds = (np.arange(dim), np.arange(dim))
    log_diags = np.log(np.diag(mat))
    return(jax.ops.index_update(mat, diag_inds, log_diags))

mat = onp.random.random((3, 3))
print(mat)
print(_exp_matrix_diagonal(mat))
print(jax.jacobian(_exp_matrix_diagonal)(mat))

# %%
np.triu_indices(5)

def pack_vec(vec, dim):
    assert len(vec) == dim * (dim + 1) / 2
    mat = np.zeros((dim, dim))
    inds = np.tril_indices(dim)
    return(jax.ops.index_update(mat, inds, vec))

vec = np.arange(0, 6, dtype=np.float32) + 1
print(vec.dtype)
print(pack_vec(vec, 3))

print('Raw:')
print(jax.jacobian(pack_vec)(vec, 3))

print('JIT:')
jac_fun = jit(jax.jacobian(pack_vec), static_argnums=1)
print(jac_fun(vec, 3))

# %%
# Fails

# @custom_jvp
# def replace_ind(x, v, i):
#     x[i] = v
#     return x

# replace_ind.defjvps(
#     lambda x_dot, ans, x, v, i: replace_ind(x_dot, 0.0, i),
#     lambda v_dot, ans, x, v, i: replace_ind(ans, v_dot, i),
#     None)

# x = np.array([1.0, 2.0, 3.5])
# replace_ind(x, 10.0, 1)

# %% [markdown]
# ## Why is jax slow?

# %%
import timeit
foo = np.random.random((100, 10, 7)) + 1
number = 1000


def _unconstrain_array(array, lb, ub, np):
    # Assume that the inputs obey the constraints, lb < ub and
    # lb <= array <= ub, which are checked in the pattern.
    if ub == float("inf"):
        if lb == -float("inf"):
            # For consistent behavior, never return a reference.
            # Note that deepcopy will cause jax to fail.
            return copy.copy(array)
        else:
            return np.log(array - lb)
    else:  # the upper bound is finite
        if lb == -float("inf"):
            return -1 * np.log(ub - array)
        else:
            return np.log(array - lb) - np.log(ub - array)

setup_str = "from __main__ import jnp, np, foo, _unconstrain_array"
print(timeit.timeit('_unconstrain_array(foo, lb=0.5, ub=10.0, np=jnp)', setup=setup_str, number=number))
print(timeit.timeit('_unconstrain_array(foo, lb=0.5, ub=10.0, np=np)', setup=setup_str, number=number))

# %%
import timeit
foo = np.random.random((100, 10, 7)) + 1
number = 5000

setup_str = "from __main__ import jnp, np, foo"
print(timeit.timeit('jnp.atleast_1d(foo)', setup=setup_str, number=number))
print(timeit.timeit('np.atleast_1d(foo)', setup=setup_str, number=number))

# %%
import timeit
foo = np.random.random((100, 10, 7)) + 1
number = 5000

setup_str = "from __main__ import jnp, np, foo"
print(timeit.timeit('jnp.all(foo < 0.)', setup=setup_str, number=number))
print(timeit.timeit('np.all(foo < 0.)', setup=setup_str, number=number))

# %%
import jax
import jax.numpy as jnp
import numpy as np

import timeit
foo = [ np.random.random((100, )) for _ in range(10) ]
number = 500

@jax.jit
def jitted_fun(x):
    return jnp.hstack(x)

setup_str = "from __main__ import jnp, np, foo, jitted_fun"
print(timeit.timeit('y = jnp.hstack(foo)', setup=setup_str, number=number))
print(timeit.timeit('y = jitted_fun(foo)', setup=setup_str, number=number))
print(timeit.timeit('y = np.hstack(foo)', setup=setup_str, number=number))

# %% [markdown]
# # Is this even going to work

# %%
class BasePattern():
    def __init__(self, scale):
        self._scale = scale + 1.0
    
    def fun(self, val):
        return val

class Pattern(BasePattern):
    
    def get_scale(self):
        return self._scale

    def fun(self, val):
        if self._scale < 0.0:
            return 0.0
        return self.get_scale() * val
    
pattern = Pattern(2.1)
      
jit_fun = jax.jit(pattern.fun)
print(jit_fun(5.0))

jit_grad = jax.jit(jax.grad(pattern.fun))
print(jit_grad(5.0))

# %% [markdown]
# # Profiling psd functions
#
# All these are actually comparable between jax and autograd.

# %%
import cProfile
import pstats
valid_value = pattern.random()

# Execute required methods.
profile = True

if profile:
    pr = cProfile.Profile()
    pr.enable()

from paragami.psdmatrix_patterns import \
    _vectorize_ld_matrix, _unvectorize_ld_matrix, \
    _pack_posdef_matrix, _unpack_posdef_matrix

mat = jax_random((30, 30))
mat = mat @ mat + 100 * np.eye(30)
val = _vectorize_ld_matrix(mat)
#jit_fun = jax.jit(_vectorize_ld_matrix); jit_fun(mat)
#jit_fun = jax.jit(_unvectorize_ld_matrix); jit_fun(val)
#jit_fun = jax.jit(_pack_posdef_matrix); jit_fun(mat)
jit_fun = jax.jit(_unpack_posdef_matrix); jit_fun(val)

tic = time.time()
for _ in range(100):
    jit_fun(val)
    
tic = time.time() - tic; print(tic)

if profile:
    pr.disable()

# %%
# ps = pstats.Stats(pr).strip_dirs().sort_stats('cumulative')
# ps.print_stats()

# %% [markdown]
# # Hashing

# %%
class HashableDict():
    def __init__(self, d):
        self._d = d
    
    def __hash__(self):
        return hash(tuple(self._d.keys()) + tuple(self._d.values()))
    
    def __eq__(self, a):
        print(a.keys() == self._d.keys())
        print(a.values(), self._d.values())
        print(a.values() == self._d.values())
        return a.keys() == self._d.keys() and a.values() == self._d.values()
    
d = { 'a': int(5), 'b': int(6)}

dclass = HashableDict(d)

print(hash(dclass))

print(dclass == { 'a': int(5), 'b': int(6)})
print(dclass == d)
# Out:
# -2803890154430002440
# True
# dict_values([5, 6]) dict_values([5, 6])
# False
# False
# True
# dict_values([5, 6]) dict_values([5, 6])
# False
# False
