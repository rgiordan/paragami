# %%
class foo():
    def __init__(self, a):
        self.a = a
        
    def add(self, b, a=self.a):
        return b + a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-211407c88552> in <module>
# ----> 1 class foo():
#       2     def __init__(self, a):
#       3         self.a = a
#       4
#       5     def add(self, b, a=self.a):
#
# <ipython-input-1-211407c88552> in foo()
#       3         self.a = a
#       4
# ----> 5     def add(self, b, a=self.a):
#       6         return b + a
#
# NameError: name 'self' is not defined
